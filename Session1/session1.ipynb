# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install mysql-connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install SQLAlchemy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install scikit-learn
# Out:
# ...
#
# ...

# %% [markdown]
# Загрузим данные dataset.csv в реляционную базу данных Mysql и затем используем эти данные с загрузкой в соответствующий dataframe.

# %%
import pandas as pd
import mysql.connector
from sqlalchemy import create_engine

db_username = 'root'
db_password = '@Va&V12#12A27'
db_host = '127.0.0.1'
db_name = 'ds_session_one'

# подключение к базе данных
engine = create_engine(f'mysql+mysqlconnector://{db_username}:{db_password}@{db_host}/{db_name}')

# %% [markdown]
# Загрузим данные из файла dataset.csv

# %%
file_path = 'dataset.csv'
df = pd.read_csv(file_path)

df.head(15)
# Out:
#     Unnamed: 0        player_name team_abbreviation   age  player_height  \
# 0            0      Dennis Rodman               CHI  36.0         198.12
# 1            1  Dwayne Schintzius               LAC  28.0         215.90
# 2            2       Earl Cureton               TOR  39.0         205.74
# 3            3        Ed O'Bannon               DAL  24.0         203.20
# 4            4        Ed Pinckney               MIA  34.0         205.74
# 5            5      Eddie Johnson               HOU  38.0         200.66
# 6            6        Eddie Jones               LAL  25.0         198.12
# 7            7     Elden Campbell               LAL  28.0         213.36
# 8            8  Eldridge Recasner               ATL  29.0         193.04
# 9            9       Elliot Perry               MIL  28.0         182.88
# 10          10      Elmer Bennett               DEN  27.0         182.88
# 11          11     Elmore Spencer               SEA  27.0         213.36
# ...

# %% [markdown]
# Загрузим данные в таблицу MySQL

# %%
table_name = 'basketball_stats'
df.to_sql(table_name, engine, if_exists='replace', index=False)
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# d:\anaconda3\lib\site-packages\mysql\connector\connection_cext.py in _open_connection(self)
#     290         try:
# --> 291             self._cmysql.connect(**cnx_kwargs)
#     292             self._cmysql.converter_str_fallback = self._converter_str_fallback
#
# MySQLInterfaceError: Unknown MySQL server host 'Va&V12#12A27@127.0.0.1' (11003)
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# d:\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3279         try:
# -> 3280             return fn()
#    3281         except dialect.dbapi.Error as e:
#
# d:\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     309         """
# ...
